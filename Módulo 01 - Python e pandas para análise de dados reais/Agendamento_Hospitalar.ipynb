# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandre-guerra/Angular-CRUD/blob/master/M%C3%B3dulo%2001%20-%20Python%20e%20pandas%20para%20an%C3%A1lise%20de%20dados%20reais/Agendamento_Hospitalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analisando dados do SUS de 2008 para frente

# %%
#importação das libs
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
#importando os dados e exibindo
df = pd.read_csv("/content/drive/My Drive/Bootcamp Alura/Modulo-1/A160324189_28_143_208.csv", delimiter=";", 
                    encoding="ISO-8859-1", skiprows=3, skipfooter=12, decimal=",", thousands=".")

df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unidade da Federação  1992/Mar  ...      2020/Ago          Total
# 0              11 Rondônia         -  ...    3556381.57   929129659.72
# 1                  12 Acre         -  ...             -   420668039.63
# 2              13 Amazonas         -  ...    4726485.73  1771654871.23
# 3               14 Roraima         -  ...    1524478.04   305010883.18
# 4                  15 Pará         -  ...   11559714.54  4437115730.71
# 5                 16 Amapá         -  ...     834187.31   291637984.75
# 6             17 Tocantins         -  ...    2453362.74   999998621.85
# 7              21 Maranhão         -  ...   10916718.78  3632860959.84
# ...

# %%
df.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
df.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago          Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38 11958647088.33
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2172157981.36
# 24         51 Mato Grosso        -  ...   6174224.99  2036923784.59
# 25               52 Goiás        -  ...  20242641.73  4657348958.66
# 26    53 Distrito Federal        -  ...  12044848.02  2429933198.76
#
# [5 rows x 280 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
pd.options.display.float_format = "{:.2f}".format
df.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
df['2008/Ago']
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
df['2008/Ago'].mean()
# Out:
# 26636409.892222222

# %%
df.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,7))

# %%
ax = df.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Total de gastos com procedimentos hospitalares do SUS em Agosto/2008")
plt.show()

# %%
#Desafio 2 - Fazer o mesmo gráfico para o mês mais atual

#criando uma cópia dos dados
df2 = df

# #Tentando gerar o gráfico
# ax2 = df2.plot(x='Unidade da Federação', y='2020/Ago', kind='bar', 
#                figsize=(10,7))
# ax2.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
# plt.title("Total de gastos com procedimentos hospitalares do SUS" 
#           + "por unidade da federação em Agosto/2020")
# plt.show()

#Deu erro por que temos um tipo de dado inválido na coluna 2020/Ago

# %%
#Convertendo o campo 2020/Ago para numérico e deixando o que não for numérico como nan
df2['2020/Ago'] = pd.to_numeric(df2['2020/Ago'], errors='coerce')
df2.info
# Out:
# <bound method DataFrame.info of       Unidade da Federação  1992/Mar  ...     2020/Ago          Total
# 0              11 Rondônia         -  ...   3556381.57   929129659.72
# 1                  12 Acre         -  ...          nan   420668039.63
# 2              13 Amazonas         -  ...   4726485.73  1771654871.23
# 3               14 Roraima         -  ...   1524478.04   305010883.18
# 4                  15 Pará         -  ...  11559714.54  4437115730.71
# 5                 16 Amapá         -  ...    834187.31   291637984.75
# 6             17 Tocantins         -  ...   2453362.74   999998621.85
# 7              21 Maranhão         -  ...  10916718.78  3632860959.84
# 8                 22 Piauí         -  ...   7926321.69  2130616492.35
# 9                 23 Ceará         -  ...  14559529.59  6197357245.98
# 10  24 Rio Grande do Norte         -  ...   8080160.97  2477372149.60
# 11              25 Paraíba         -  ...   8585226.08  2470550104.25
# ...

# %%
#criando um novo dataframe e substituindo os valores nan por 0.00
df3 = df2.fillna(value=0.00)

#ordenando o df por valor
df3 = df2.sort_values('2020/Ago', ascending=False)

df3.info
# Out:
# <bound method DataFrame.info of       Unidade da Federação  1992/Mar  ...     2020/Ago          Total
# 19            35 São Paulo  40243.16  ... 140414944.95 38929353900.57
# 16         31 Minas Gerais         -  ...  57473699.06 19160106499.88
# 20               41 Paraná         -  ...  41542401.16 13786964617.27
# 18       33 Rio de Janeiro         -  ...  36264322.65  9696362872.68
# 12           26 Pernambuco         -  ...  33544876.14  8046954289.39
# 22    43 Rio Grande do Sul         -  ...  28349257.38 11958647088.33
# 15                29 Bahia         -  ...  26023558.53  9193802684.16
# 25                52 Goiás         -  ...  20242641.73  4657348958.66
# 21       42 Santa Catarina         -  ...  16991236.43  7324100054.96
# 9                 23 Ceará         -  ...  14559529.59  6197357245.98
# 26     53 Distrito Federal         -  ...  12044848.02  2429933198.76
# 4                  15 Pará         -  ...  11559714.54  4437115730.71
# ...

# %%
#Recriando o gráfico após as correções nos dados

df3['2020/Ago'] = df3['2020/Ago']/1000000
ax3 = df3.plot(x='Unidade da Federação', y='2020/Ago', kind='barh', 
               figsize=(15,10), color='red', legend=False)

ax3.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Total de gastos com procedimentos hospitalares do SUS " 
          + "por unidade da federação em Agosto/2020", size=15)

plt.ylabel("Unidades da Federação", size=15)
plt.xlabel("Gastos em Milhões por UF", size=15)
plt.show()

# %% [markdown]
# # Agora fazendo a análise para dois meses

# %%
dados = df3
dados[['2008/Ago','2008/Set']].head()
# Out:
#        2008/Ago     2008/Set
# 19 179898070.22 180082203.71
# 16  80374117.08  82400146.79
# 20  56699001.13  58091985.79
# 18  42487939.51  43066461.47
# 12  31705296.79  30703879.20

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# 2020/Ago           19.88
# Total      5993724452.01
# Length: 158, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#    Unidade da Federação   2007/Ago  ...  2020/Ago          Total
# 19         35 São Paulo 1665349.90  ...    140.41 38929353900.57
# 16      31 Minas Gerais  971394.37  ...     57.47 19160106499.88
# 20            41 Paraná  554800.22  ...     41.54 13786964617.27
# 18    33 Rio de Janeiro  469469.34  ...     36.26  9696362872.68
# 12        26 Pernambuco  400640.85  ...     33.54  8046954289.39
#
# [5 rows x 159 columns]

# %%
usaveis = usaveis.set_index('Unidade da Federação')
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...  2020/Ago          Total
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ...    140.41 38929353900.57
# 31 Minas Gerais       971394.37 2861781.50  ...     57.47 19160106499.88
# 41 Paraná             554800.22 1431708.01  ...     41.54 13786964617.27
# 33 Rio de Janeiro     469469.34  921646.57  ...     36.26  9696362872.68
# 26 Pernambuco         400640.85 1088340.42  ...     33.54  8046954289.39
#
# [5 rows x 158 columns]

# %%
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# 2020/Ago            nan
# Total      420668039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  35 São Paulo  31 Minas Gerais  ...  16 Amapá   12 Acre
# 2007/Ago                1665349.90        971394.37  ...  33672.74  10470.07
# 2007/Set                4434168.64       2861781.50  ... 104822.98  14001.71
# 2007/Out               14577395.84      10018011.35  ... 118378.28  86200.85
# 2007/Nov               35032259.98      21730281.63  ... 226661.18 301323.68
# 2007/Dez               76668547.41      43429517.54  ... 844019.90 769612.36
#
# [5 rows x 27 columns]

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação   35 São Paulo  31 Minas Gerais  ...     16 Amapá      12 Acre
# 2020/Mai               302857660.98     136867275.75  ...   2701014.87   2383895.48
# 2020/Jun               299060851.62     135977571.87  ...   2699492.23   2199920.70
# 2020/Jul               282709570.31     120467187.34  ...   2155083.37   1163813.08
# 2020/Ago                     140.41            57.47  ...         0.83          nan
# Total                38929353900.57   19160106499.88  ... 291637984.75 420668039.63
#
# [5 rows x 27 columns]

# %%
usaveis = usaveis.drop('Total', axis=1)
usaveis.T.tail()
# Out:
# Unidade da Federação  35 São Paulo  31 Minas Gerais  ...   16 Amapá    12 Acre
# 2020/Abr              251696362.66     126330649.86  ... 1774558.12 2472063.08
# 2020/Mai              302857660.98     136867275.75  ... 2701014.87 2383895.48
# 2020/Jun              299060851.62     135977571.87  ... 2699492.23 2199920.70
# 2020/Jul              282709570.31     120467187.34  ... 2155083.37 1163813.08
# 2020/Ago                    140.41            57.47  ...       0.83        nan
#
# [5 rows x 27 columns]

# %%
ax_usaveis = usaveis.T.plot(figsize=(15,10))

ax_usaveis.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5), title='UF')
plt.title("Total de gastos com procedimentos hospitalares do SUS" 
          + "por unidade da federação ao longo dos anos", size=15)

plt.xlabel("Ano/Mês", size=15)
plt.ylabel("Gastos x Ano/Mês", size=15)

plt.show()

# %% [markdown]
# # Selecionando somente 5 colunas

# %%
# usaveis.loc['12 Acre']
usaveis.index
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '41 Paraná', '33 Rio de Janeiro',
#        '26 Pernambuco', '43 Rio Grande do Sul', '29 Bahia', '52 Goiás',
#        '42 Santa Catarina', '23 Ceará', '53 Distrito Federal', '15 Pará',
#        '21 Maranhão', '32 Espírito Santo', '25 Paraíba',
#        '24 Rio Grande do Norte', '22 Piauí', '27 Alagoas', '51 Mato Grosso',
#        '13 Amazonas', '50 Mato Grosso do Sul', '11 Rondônia', '17 Tocantins',
#        '28 Sergipe', '14 Roraima', '16 Amapá', '12 Acre'],
#       dtype='object', name='Unidade da Federação')

# %%
selecionados = usaveis.loc[['35 São Paulo', '31 Minas Gerais','41 Paraná', '33 Rio de Janeiro',
             '42 Santa Catarina' ]]

ax_select = selecionados.T.plot(figsize=(12,10))
ax_select.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Total de gastos com procedimentos hospitalares do SUS" 
          + "por unidade da federação ao longo dos anos", size=15)
plt.xlabel("Ano/Mês", size=15)
plt.ylabel("Gastos x Ano/Mês", size=15)

plt.show()
